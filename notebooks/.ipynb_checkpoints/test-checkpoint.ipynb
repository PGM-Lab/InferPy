# %%
import inferpy as inf
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-db62ddd3a029> in <module>()
# ----> 1 import inferpy as inf
#
# ImportError: No module named inferpy

# %%
print(inf.VERSION)
